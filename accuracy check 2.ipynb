# %% [markdown]
# # Mode-Turbulence Coupling: Numerical Analysis
# # Accuracy check
#
# ## Two Runs:
# ## 1. dTau = 2*pi/100
# ## 2. dTau = 2*pi/200
# ## all other quantities the same

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import random
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy.interpolate as interpolate
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Physical Parameters

# %%
# mach number Ma
Ma = 0.025 ** (1/2)
K = 1
eta = 1

# %% [markdown]
# ## Functions of Ma

# %%
meandeltaT = 2*np.pi

# variables for generating F1
stdF1 = eta * Ma**2 / (2 * np.pi)
limitY1 = eta / (2 * np.pi)

# variables for generating F2 and G1
stdF2 = eta * Ma**2
limitY2 = eta

# %% [markdown]
# ## Calculation parameters

# %%
L = 1
M = 10**4
M_short = 200
N = 1
m = 10**2

# dTau is the time step for the Runge Kutta Method
dTau = 2*np.pi/100
dTau_2ndrun = 2*np.pi/200
Tr = K * meandeltaT

# %% [markdown]
# ## Calculation relations

# %%
 Tmax = 2 * np.pi * M
# delt = N * deltaT

# %% [markdown]
# ## Initial Conditions

# %%
# initial conditions A(0)=1/2*std_F2, dA/dT(0)=0
initial_dAdT = 0
initial_AT = 0

# %%
n_bins = 200

axis_font = {'size':'30'}
title_font = {'size':'40'}

# %% [markdown]
# ## Functions

# %%
# Source: https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.rayleigh.html
#deltaT is the length of each eddy turnover
def fundeltaT(n_bins, M, dTau):
    deltaT = []
    rayleigh = np.random.rayleigh(meandeltaT, M)                           
    hist, bin_edges = np.histogram(rayleigh, bins=n_bins, density=True)
    cum_values = np.zeros(bin_edges.shape)
    cum_values[1:] = np.cumsum(hist*np.diff(bin_edges))
    inv_cdf = interpolate.interp1d(cum_values, bin_edges)
    # ensure that deltaT is a multiple of dTau
    for i in range(M):
        r = np.random.rand(1)
        deltaTtemp = inv_cdf(r)
        if (deltaTtemp % dTau < 0.005):
            deltaTtemp2 = deltaTtemp - (deltaTtemp % dTau)
        else:
            deltaTtemp2 = deltaTtemp + dTau - (deltaTtemp % dTau)
        deltaT.append(deltaTtemp2)
    count, bins, ignored = plt.hist(rayleigh, 80, density=True)
    plt.title("Rayleigh Distribution")
    plt.xlabel("Delta T")
    plt.show()
    return deltaT




# Tturb adds up the delta T's
def funTturb(deltaT):
    Tturb=[0]
    for i in range(len(deltaT)-1):
        Tturb.append(deltaT[i]+Tturb[i])
    time=Tturb
    time.pop(-1)
    return Tturb, time



# generating F1, F2, G1
def funF_k(F_k, std, limit, deltaT, Tturb):
    time = []
    y1 = 0
    for i in range(len(deltaT) - 1):
        Tn = ((deltaT[i] + deltaT[i+1]) / 2)
        stdevt = ((1 - math.exp(-2 * Tn / Tr)) * std ** 2) ** (1/2)
        meant = math.exp(-Tn / Tr) * y1
        # y1 is chosen from markov conditional probability function
        # put limit on y1
            # set y1 > limitY1 so that while loop only ends when y1 < limitY1
        y1 = limit + 1
        while abs(y1) > limit:
            y1 = np.random.normal(meant, stdevt, 2)[0]
        Ttemp = np.linspace(0, deltaT[i], deltaT[i] / dTau)
        # loops through each eddy
        for j in Ttemp:
            x = j / deltaT[i][0]
            if j == deltaT[i]:
                pass
            else:
                time.append(j+Tturb[i])
                F_k.append(16 * y1 * x**2 * (1 - x)**2)
    return F_k, time


def funAmp(Amp, time, F1, F2, G1, dTau):
    # Runge Kutta

    # A'' = f(T, A, A') = -F1 * A' - ( 1 + G1) A + F2
    # A' = u
    # u' = f(T, A, u) = -F1 * u - ( 1 + G1) A + F2
    # A'(0) = 0

    t = 0.0
    A = Amp[0]
    u = 0
    
    for i in range(len(time)):
        m1 = u
        k1 = -(F1[i] * u) - ( 1 + G1[i] ) * A + F2[i]
        m2 = u + (dTau / 2.) * k1
        t_2 = t + (dTau / 2)
        A_2 = A + (dTau / 2) * m1
        u_2 = m2
        k2 = -(F1[i] * u_2) - ( 1 + G1[i] ) * A_2 + F2[i]
        m3 = u + (dTau / 2) * k2
        t_3 = t + (dTau / 2)
        A_3 = A + (dTau / 2) * m2
        u_3 = m3
        k3 = -(F1[i] * u_3) - ( 1 + G1[i] ) * A_3 + F2[i]
        m4 = u + dTau *k3
        t_4 = t + dTau
        A_4 = A + dTau * m3
        u_4 = m4
        k4 = -(F1[i] * u_4) - ( 1 + G1[i] ) * A_4 + F2[i]
        t = t + dTau 
        A = A + (dTau / 6.) * (m1 + (2. * m2) + (2. * m3) + m4)
        u = u + (dTau / 6.) * (k1 + (2. * k2) + (2. * k3) + k4)
        Amp.append(A)

    Amp = Amp[:-1]
    
    return Amp




# Average value of Amplitude
def FunAsqr(A):
    Asqr = []
    for i in A:
        Asqr.append(i**2)
    return Asqr




# log(A)
def FunLog(A):
    logA = []
    for i in A:
        logA.append(math.log10(abs(i)))
    return logA




# Root mean square
def FunRMS(A):
    Asqr = []
    for i in A:
        Asqr.append(i**2)
    avg = np.sum(Asqr) / len(Asqr)
    RMS = avg**(1/2)
    return RMS
    
    
    
def funAlpha(A, t, alpha):

    # root mean square of amplitude for T(max)
    Abar_max = FunRMS(A)

    # the number of time segments is the total time (Tmax)/delT
    numsegments = int(Tmax/int(sum(delt)/len(delt)))+1

    # 2d array containing an array for amplitudes in each segments
    ampsegments = []

    # this loop divides the total duration T(max) into equal segments of delT
    # and adds corresponding amplitudes in each time segment to amsegments 
    i=0
    for count in range(0, numsegments):
        # amp segment contains the amplitudes in the specified time segment
        ampsegment = []
        # checks if that time is withint the correct time segment
        while i < len(t)-1:
            if (t[i] < (count+1)*2*np.pi):
                # adds the corresponding amplitude if the time is within specified time segment
                ampsegment.append(A[i])
                i+=1
            else:
                # breaks the while loop if the time is outside the time segment 
                # and moves to the next time segment
                break        
        ampsegments.append(ampsegment)


    # take Abar(T) = rms(A in delT)
    # Abar is the root mean square (RMS) of A in delT   
    Abar = []    
    for ampsegment in ampsegments:
        Abar.append(FunRMS(ampsegment))

    # in order to better exhibit the distribution of the full range of values of Abar, use instead
    # alpha = log(Abar) so -4 <= alpha <= 0
    tempalpha = FunLog(Abar)
    alpha.append(tempalpha)

    alpha_max = max(tempalpha)
    alpha_min = min(tempalpha)
    
    return alpha




# flattens nested arrays into one dimensional arrays
def flatten(input):
    new_list = []
    for i in input:
        for j in i:
            new_list.append(j)
    return new_list

# %% [markdown]
# ##  F1, Amplitude of mode, F2 vs. Time for all runs

# %% [markdown]
# ### Evolution 1

# %%
deltaT = fundeltaT(n_bins, M, dTau)

Tturb, time = funTturb(deltaT)

# %%
# generate F1

F1 = []
F1, time = funF_k(F1, stdF1, limitY1, deltaT, Tturb)

plt.hist(F1, 20)
plt.title("F1")
plt.show()

# generate F2

F2 = []
F2, time = funF_k(F2, stdF2, limitY2, deltaT, Tturb)

plt.hist(F2, 20)
plt.title("F2")
plt.show()

# generate G1

G1 = []
G1, time = funF_k(G1, stdF2, limitY2, deltaT, Tturb)

plt.hist(G1, 20)
plt.title("G1")
plt.show()

# generate Amp
# Amp with contain amplitudes of current run

Amp = [initial_AT]
Amp_2ndrun = [initial_AT]

Amp = funAmp(Amp, time, F1, F2, G1, dTau)
Amp_2ndrun = funAmp(Amp_2ndrun, time, F1, F2, G1, dTau_2ndrun)
# Out:
# /Users/celiatandon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:53: DeprecationWarning: object of type <class 'numpy.ndarray'> cannot be safely interpreted as an integer.

# %%
# plot all plots 
print ("long run:")
    
plt.figure(figsize=(40,10))    
plt.plot(time, F1, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('F\u2081', **axis_font)
plt.tight_layout()
plt.show()

plt.figure(figsize=(40,10))
plt.plot(time, F2, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('F\u2082', **axis_font)
plt.tight_layout()
plt.show()
    
plt.figure(figsize=(40,10))
plt.plot(time, G1, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('G\u2081', **axis_font)
plt.tight_layout()
plt.show()

print ("Run 1: dTau = 2*pi/100")

plt.figure(figsize=(40,10))
plt.plot(time, Amp, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('Amplitude', **axis_font)
plt.tight_layout()
plt.show()

print ("Run 2: dTau = 2*pi/200")

plt.figure(figsize=(40,10))
plt.plot(time, Amp_2ndrun, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('Amplitude', **axis_font)
plt.tight_layout()
plt.show()

# plot the shorter plot
duration = 2 * np.pi * M_short
tshort = []
Ashort = []
Ashort_2ndrun = []
f1short = []
f2short = []
g1short = []
# start the shorter plot a third of the way through the run
start_index = int(len(time)/3)
index = start_index
while time[index] < (duration + time[start_index]):
    tshort.append(time[index])
    Ashort.append(Amp[index])
    Ashort_2ndrun.append(Amp_2ndrun[index])
    f1short.append(F1[index])
    f2short.append(F2[index])
    g1short.append(G1[index])
    index +=1
    
# plot all plots
print ("short run:")
    
plt.figure(figsize=(40,10))    
plt.plot(tshort, f1short, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('F\u2081', **axis_font)
plt.tight_layout()
plt.show()

plt.figure(figsize=(40,10))
plt.plot(tshort, f2short, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('F\u2082', **axis_font)
plt.tight_layout()
plt.show()
    
plt.figure(figsize=(40,10))
plt.plot(tshort, g1short, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('G\u2081', **axis_font)
plt.tight_layout()
plt.show()

print ("Run 1: dTau = 2*pi/100")

plt.figure(figsize=(40,10))
plt.plot(tshort, Ashort, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('Amplitude', **axis_font)
plt.tight_layout()
plt.show()

print ("Run 2: dTau = 2*pi/200")

plt.figure(figsize=(40,10))
plt.plot(tshort, Ashort_2ndrun, 'k')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel(r'$\tau$', **axis_font)
plt.ylabel('Amplitude', **axis_font)
plt.tight_layout()
plt.show()
# Out:
# long run:
# Run 1: dTau = 2*pi/100
# Run 2: dTau = 2*pi/200
# short run:
# Run 1: dTau = 2*pi/100
# Run 2: dTau = 2*pi/200

# %% [markdown]
# ### Evolutions 2 - L

# %%
delt = N * deltaT

# %%
alpha = []
alpha_2ndrun = []

funAlpha(Amp, time, alpha)
alpha = flatten(alpha)

funAlpha(Amp_2ndrun, time, alpha_2ndrun)
alpha_2ndrun = flatten(alpha_2ndrun)

# %% [markdown]
# ## Amplification Distribution Function

# %%
# divide the full range alpha_min <= alpha <= alpha_max into n equal intervals
# delalpha = (alpha_max - alpha_min) / n ~ 4/n

alpha_max = max(alpha)
alpha_min = min(alpha)
delalpha = (alpha_max - alpha_min) / m

# plot delf / delalpha vs. alpha
# where delf is the fraction of collected values of alpha within each bin of width delalpha

print ("Run 1: dTau = 2*pi/100")
histogram = plt.hist(alpha, m, density=True, color='k')
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.ylabel('df/d'r'$ \alpha $', **axis_font)
plt.xlabel(r'$ \alpha $', **axis_font)
plt.show()

print ("Run 2: dTau = 2*pi/200")
histogram2 = plt.hist(alpha_2ndrun, m, density=True, color='k')
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.ylabel('df/d'r'$ \alpha $', **axis_font)
plt.xlabel(r'$ \alpha $', **axis_font)
plt.show()
# Out:
# Run 1: dTau = 2*pi/100
# Run 2: dTau = 2*pi/200

# %% [markdown]
# ## Cumulative Distribution Function

# %%
# CDF2 = int (df/dalpha) wrt dalpha from alpha to alpha_max
#      = 1 - CDF1
#      = 1 - int (df/dalpha) wrt dalpha from alpha_min to alpha

CDF2 = []
CDF2_2ndrun = []

# alpha and dfdalpha values pulled from histogram above
alpha_values = histogram[1]
dfdalpha = histogram[0]
alpha_values = np.delete(alpha_values, 0)

alpha_values_2ndrun = histogram2[1]
dfdalpha_2ndrun = histogram2[0]
alpha_values_2ndrun = np.delete(alpha_values_2ndrun, 0)

index_max = len(alpha_values)-1
index_max_2ndrun = len(alpha_values_2ndrun)-1

for index in range(len(dfdalpha)):
    index_start = index
    sum = 0
    for index_current in range(index_start, index_max):
        sum += dfdalpha[index_current] * alpha_values[index_current]
    CDF2.append(1-sum)
    
for index in range(len(dfdalpha_2ndrun)):
    index_start = index
    sum = 0
    for index_current in range(index_start, index_max_2ndrun):
        sum += dfdalpha_2ndrun[index_current] * alpha_values_2ndrun[index_current]
    CDF2_2ndrun.append(1-sum)
    
normalization_factor = CDF2[0]
normalization_factor_2ndrun = CDF2_2ndrun[0]

CDF2_norm = []
for value in CDF2:
    CDF2_norm.append(value/normalization_factor)
    
CDF2_norm_2ndrun = []
for value in CDF2_2ndrun:
    CDF2_norm_2ndrun.append(value/normalization_factor_2ndrun)
    
CDF2_norm = np.array(CDF2_norm)
CDF2_norm_2ndrun = np.array(CDF2_norm_2ndrun)

# %%
print ("Run 1: dTau = 2*pi/100")
plt.plot(alpha_values, CDF2_norm,  color='k')
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.ylabel('CDF2', **axis_font)
plt.xlabel(r'$ \alpha $', **axis_font)
plt.show()

print ("Run 2: dTau = 2*pi/200")
plt.plot(alpha_values_2ndrun, CDF2_norm_2ndrun,  color='k')
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.ylabel('CDF2', **axis_font)
plt.xlabel(r'$ \alpha $', **axis_font)
plt.show()
# Out:
# Run 1: dTau = 2*pi/100
# Run 2: dTau = 2*pi/200

# %% [markdown]
# ## Values for table

# %%
print("K = ", K)
print("eta * Ma**2 = ", eta * Ma**2)

print("\n")

F2rms = FunRMS(F2)
print("<F2^2>^(1/2) = ", F2rms)
print("Maximum Value of F2 ", max(F2))
print("Minimum Value of F2 ", min(F2))

print("\n")

F1rms = FunRMS(F1)
print("<F1^2>^(1/2) = ", F1rms)
print("Maximum Value of F1 ", max(F1)) 
print("Minimum Value of F1 ", min(F1))

print("\n")

print ("Run 1: dTau = 2*pi/100")
G1rms = FunRMS(G1)
print("<G1^2>^(1/2) = ", G1rms)
print("Maximum Value of G1 ", max(G1)) 
print("Minimum Value of G1 ", min(G1))

print("\n")

print ("Run 1: dTau = 2*pi/100")
Asqr = FunAsqr(Amp)
avg = np.sum(Asqr) / len(Asqr)
print("<A^2> = ", avg)

print("\n")
print ("Run 2: dTau = 2*pi/200")
Asqr_2ndrun = FunAsqr(Amp_2ndrun)
avg_2ndrun = np.sum(Asqr_2ndrun) / len(Asqr_2ndrun)
print("<A^2> = ", avg_2ndrun)
# Out:
# K =  1
# eta * Ma**2 =  0.025
#
#
# <F2^2>^(1/2) =  0.01585728012850812
# Maximum Value of F2  0.09262396781323974
# Minimum Value of F2  -0.11307242650997551
#
#
# <F1^2>^(1/2) =  0.0025316153807585636
# Maximum Value of F1  0.014638931190113186
# Minimum Value of F1  -0.01607477891945229
#
#
# Run 1: dTau = 2*pi/100
# <G1^2>^(1/2) =  0.0160551411033898
# Maximum Value of G1  0.09391269255867962
# Minimum Value of G1  -0.09387535817014012
#
#
# Run 1: dTau = 2*pi/100
# <A^2> =  1.1236767074492648
#
#
# Run 2: dTau = 2*pi/200
# <A^2> =  5.086224206777323
